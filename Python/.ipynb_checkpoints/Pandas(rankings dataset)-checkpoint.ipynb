# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Lenovo\Downloads\rankings.csv")
print(df)
# Out:
#      2025 Rank  2024 Rank                              Institution Name  \
# 0            1          1  Massachusetts Institute of Technology (MIT)
# 1            2          6                       Imperial College London
# 2            3          3                          University of Oxford
# 3            4          4                            Harvard University
# 4            5          2                       University of Cambridge
# ...        ...        ...                                           ...
# 1498     1401+  1201-1400               University of Montana Missoula
# 1499     1401+      1401+                          University of Oradea
# 1500     1401+  1201-1400                      University of San Carlos
# 1501     1401+      1401+      University Politehnica of Timisoara, UPT
# 1502     1401+      1401+                 Western Washington University
#
#      Location   Location Full Size  Academic Reputation  Employer Reputation  \
# ...

# %%
print(df.head())
# Out:
#   2025 Rank 2024 Rank                              Institution Name Location  \
# 0         1         1  Massachusetts Institute of Technology (MIT)        US
# 1         2         6                       Imperial College London       UK
# 2         3         3                          University of Oxford       UK
# 3         4         4                            Harvard University       US
# 4         5         2                       University of Cambridge       UK
#
#     Location Full Size  Academic Reputation  Employer Reputation  \
# 0   United States    M                100.0                100.0
# 1  United Kingdom    L                 98.5                 99.5
# 2  United Kingdom    L                100.0                100.0
# 3   United States    L                100.0                100.0
# 4  United Kingdom    L                100.0                100.0
#
#    Faculty Student  Citations per Faculty  International Faculty  \
# ...

# %%
df.tail()
# Out:
#      2025 Rank  2024 Rank                          Institution Name Location  \
# 1498     1401+  1201-1400           University of Montana Missoula        US
# 1499     1401+      1401+                      University of Oradea       RO
# 1500     1401+  1201-1400                  University of San Carlos       PH
# 1501     1401+      1401+  University Politehnica of Timisoara, UPT       RO
# 1502     1401+      1401+             Western Washington University       US
#
#       Location Full Size  Academic Reputation  Employer Reputation  \
# 1498  United States    M                  3.0                  2.2
# 1499        Romania    L                  5.6                  2.2
# 1500    Philippines    M                  7.2                  9.4
# 1501        Romania    L                  4.1                  4.2
# 1502  United States    L                  2.6                  2.6
#
#       Faculty Student  Citations per Faculty  International Faculty  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1503 entries, 0 to 1502
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   2025 Rank                       1503 non-null   object
#  1   2024 Rank                       1482 non-null   object
#  2   Institution Name                1503 non-null   object
#  3   Location                        1503 non-null   object
#  4   Location Full                   1503 non-null   object
#  5   Size                            1503 non-null   object
#  6   Academic Reputation             1503 non-null   float64
#  7   Employer Reputation             1503 non-null   float64
#  8   Faculty Student                 1503 non-null   float64
#  9   Citations per Faculty           1503 non-null   float64
#  10  International Faculty           1403 non-null   float64
#  11  International Students          1445 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Academic Reputation  Employer Reputation  Faculty Student  \
# count           1503.00000          1503.000000      1503.000000
# mean              20.28656            19.786693        28.128676
# std               22.32623            23.784986        27.613017
# min                1.30000             1.100000         1.000000
# 25%                6.30000             4.300000         7.300000
# 50%               11.00000             9.400000        16.000000
# 75%               23.50000            25.300000        40.400000
# max              100.00000           100.000000       100.000000
#
#        Citations per Faculty  International Faculty  International Students  \
# count            1503.000000            1403.000000             1445.000000
# mean               23.503460              30.725374               25.580346
# std                27.870692              34.328935               31.098689
# ...

# %%
df.shape
# Out:
# (1503, 16)

# %%
df.dtypes
# Out:
# 2025 Rank                          object
# 2024 Rank                          object
# Institution Name                   object
# Location                           object
# Location Full                      object
# Size                               object
# Academic Reputation               float64
# Employer Reputation               float64
# Faculty Student                   float64
# Citations per Faculty             float64
# International Faculty             float64
# International Students            float64
# International Research Network    float64
# Employment Outcomes               float64
# Sustainability                    float64
# QS Overall Score                   object
# dtype: object

# %%
print(df["Size"])
# Out:
# 0       M
# 1       L
# 2       L
# 3       L
# 4       L
#        ..
# 1498    M
# 1499    L
# 1500    M
# 1501    L
# 1502    L
# Name: Size, Length: 1503, dtype: object

# %%
print(df[["Employment Outcomes","QS Overall Score"]])
# Out:
#       Employment Outcomes QS Overall Score
# 0                   100.0              100
# 1                    93.4             98.5
# 2                   100.0             96.9
# 3                   100.0             96.8
# 4                   100.0             96.7
# ...                   ...              ...
# 1498                  3.1                -
# 1499                  6.2                -
# 1500                  9.6                -
# 1501                  3.9                -
# 1502                  1.5                -
#
# [1503 rows x 2 columns]

# %%
print(df.loc[456])
# Out:
# 2025 Rank                                     456
# 2024 Rank                                     465
# Institution Name                  Umea University
# Location                                       SE
# Location Full                              Sweden
# Size                                            L
# Academic Reputation                          19.9
# Employer Reputation                          11.6
# Faculty Student                              71.8
# Citations per Faculty                        15.2
# International Faculty                        51.1
# International Students                       21.8
# International Research Network               78.0
# Employment Outcomes                           9.0
# Sustainability                               26.3
# QS Overall Score                             26.3
# Name: 456, dtype: object

# %%
print(df.iloc[345])
# Out:
# 2025 Rank                                        344
# 2024 Rank                                        313
# Institution Name                  University of Oulu
# Location                                          FI
# Location Full                                Finland
# Size                                               M
# Academic Reputation                             15.1
# Employer Reputation                             13.5
# Faculty Student                                 25.3
# Citations per Faculty                           59.4
# International Faculty                           65.3
# International Students                           8.6
# International Research Network                  89.4
# Employment Outcomes                             21.7
# Sustainability                                  68.6
# QS Overall Score                                32.9
# Name: 345, dtype: object

# %%
print(df.loc[456:789:3])
# Out:
#     2025 Rank 2024 Rank                                   Institution Name  \
# 456       456       465                                    Umea University
# 459       460       396  Stony Brook University, State University of Ne...
# 462       462       494                             Universidad de Sevilla
# 465       466       478                               Universität Konstanz
# 468       466       419                        Washington State University
# ..        ...       ...                                                ...
# 777   771-780  951-1000                       Université de Tunis El Manar
# 780   771-780   801-850                                  Verona University
# 783   781-790       NaN                  National University of Uzbekistan
# 786   781-790   641-650                                     The New School
# 789   781-790   801-850                               University of Latvia
#
# ...

# %%
print(df.iloc[456:789:3])
# Out:
#     2025 Rank 2024 Rank                                   Institution Name  \
# 456       456       465                                    Umea University
# 459       460       396  Stony Brook University, State University of Ne...
# 462       462       494                             Universidad de Sevilla
# 465       466       478                               Universität Konstanz
# 468       466       419                        Washington State University
# ..        ...       ...                                                ...
# 774   771-780   681-690                                  Colegio de México
# 777   771-780  951-1000                       Université de Tunis El Manar
# 780   771-780   801-850                                  Verona University
# 783   781-790       NaN                  National University of Uzbekistan
# 786   781-790   641-650                                     The New School
#
# ...

# %%
df["Size"]=="L"
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1498    False
# 1499     True
# 1500    False
# 1501     True
# 1502     True
# Name: Size, Length: 1503, dtype: bool

# %%
df[df["Size"]=="L"]
# Out:
#      2025 Rank 2024 Rank                          Institution Name Location  \
# 1            2         6                   Imperial College London       UK
# 2            3         3                      University of Oxford       UK
# 3            4         4                        Harvard University       US
# 4            5         2                   University of Cambridge       UK
# 5            6         5                       Stanford University       US
# ...        ...       ...                                       ...      ...
# 1495     1401+     1401+                     University of Craiova       RO
# 1496     1401+     1401+                     University of Lampung       ID
# 1499     1401+     1401+                      University of Oradea       RO
# 1501     1401+     1401+  University Politehnica of Timisoara, UPT       RO
# 1502     1401+     1401+             Western Washington University       US
#
# ...

# %%
df[(df["Location"]=="UK") & (df["Academic Reputation"]>50.0) & (df["Employment Outcomes"]>=65.5)]
# Out:
#    2025 Rank 2024 Rank                                   Institution Name  \
# 1          2         6                            Imperial College London
# 2          3         3                               University of Oxford
# 4          5         2                            University of Cambridge
# 8          9         9                                                UCL
# 34        34        32                       The University of Manchester
# 51        50        45  The London School of Economics and Political S...
# 68        69        67                          The University of Warwick
#
#    Location   Location Full Size  Academic Reputation  Employer Reputation  \
# 1        UK  United Kingdom    L                 98.5                 99.5
# 2        UK  United Kingdom    L                100.0                100.0
# 4        UK  United Kingdom    L                100.0                100.0
# ...

# %%
df.sort_values(by="Location")
# Out:
#       2025 Rank  2024 Rank                                 Institution Name  \
# 260         261        290                  United Arab Emirates University
# 476         477        551                                 Ajman University
# 433         434        465                            University of Sharjah
# 484         485        NaN  American University of Ras Al Khaimah ( AURAK )
# 500         501        580                             Abu Dhabi University
# ...         ...        ...                                              ...
# 869     851-900    801-850                            North-West University
# 1187  1001-1200  1001-1200                     University of the Free State
# 170         171        173                          University of Cape Town
# 295         296        283                          Stellenbosch University
# 1002   951-1000   951-1000                   University of the Western Cape
#
# ...

# %%
df.sort_values("International Students", ascending = False)
# Out:
#       2025 Rank  2024 Rank                                   Institution Name  \
# 25           26         36                                               EPFL
# 17           18         19                           The University of Sydney
# 1056  1001-1200    901-950                     London Metropolitan University
# 476         477        551                                   Ajman University
# 51           50         45  The London School of Economics and Political S...
# ...         ...        ...                                                ...
# 1474      1401+  1201-1400                   Universidad Nacional del Comahue
# 1482      1401+  1201-1400                            Universidad Veracruzana
# 1483      1401+      1401+           Universidade do Estado de Santa Catarina
# 1488      1401+      1401+  Universidade Federal do Estado do Rio de Janei...
# 1495      1401+      1401+                              University of Craiova
#
# ...

# %%
df.isnull()
# Out:
#       2025 Rank  2024 Rank  Institution Name  Location  Location Full   Size  \
# 0         False      False             False     False          False  False
# 1         False      False             False     False          False  False
# 2         False      False             False     False          False  False
# 3         False      False             False     False          False  False
# 4         False      False             False     False          False  False
# ...         ...        ...               ...       ...            ...    ...
# 1498      False      False             False     False          False  False
# 1499      False      False             False     False          False  False
# 1500      False      False             False     False          False  False
# 1501      False      False             False     False          False  False
# 1502      False      False             False     False          False  False
#
# ...

# %%
df.isnull().sum()
# Out:
# 2025 Rank                           0
# 2024 Rank                          21
# Institution Name                    0
# Location                            0
# Location Full                       0
# Size                                0
# Academic Reputation                 0
# Employer Reputation                 0
# Faculty Student                     0
# Citations per Faculty               0
# International Faculty             100
# International Students             58
# International Research Network      1
# Employment Outcomes                 0
# Sustainability                     19
# QS Overall Score                    0
# dtype: int64
