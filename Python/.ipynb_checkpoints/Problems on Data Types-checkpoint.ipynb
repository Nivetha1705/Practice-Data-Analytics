# %%
#Add 2 integers

m=int(input())
n=int(input())
o=m+n
print(o)
# Out:
#  6
#  7
# 13

# %%
#Adding 3 integers

m=int(input())
n=int(input())
o=int(input())
p=m+n+o
print(p)
# Out:
#  45
#  67
#  45
# 157

# %%
#Product of Three

m=int(input())
n=int(input())
o=int(input())
p=m*n*o
print(p)
# Out:
#  4
#  5
#  3
# 60

# %%
#Sum Combinations

a=int(input())
b=int(input())
c=int(input())
d=a+b
e=a+c
f=c+b
print(d)
print(e)
print(f)
# Out:
#  4
#  6
#  2
# 10
# 6
# 8

# %%
#Dollar to Rupee

a=int(input())
b=82.73
c=a*b
print(f"{c:.4f}")
# Out:
#  1000
# 82730.0000
