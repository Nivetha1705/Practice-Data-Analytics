# %%
import module2
print(module2.x)
print(module2.z)
print(module2.run())
module2.speak()
# Out:
# TAP ACADEMY
# True
# 25
# People of TN speak Tamil

# %%
import module2
s1=module2.Student1()
print(s1.name)
print(s1.age)
print(s1.height)
s1.sleep()
# Out:
# Uresh
# 20
# 5'10
# Uresh sleeps like a buffallo

# %%
import module2
s2=module2.Student2()
print(s2.name)
print(s2.height)
s2.code()
# Out:
# Praveen
# 5'2
# Praveen codes well

# %%
#instead of giving module2, we can give the name as we need like m
import module2 as m2
s1=m2.Student1()
print(s1.name)
print(s1.age)
print(s1.height)
s1.sleep()
import module2
s2=m2.Student2()
print(s2.name)
print(s2.height)
s2.code()
# Out:
# Uresh
# 20
# 5'10
# Uresh sleeps like a buffallo
# Praveen
# 5'2
# Praveen codes well

# %%
#We can import whatever we need only, and not the entire content from module2
from module2 import Student1, run, y,z
print(y)
print(run())
s1=Student1()# when it is imported no need to give module2.student1(), instaed we can call directly
print(s1.name)
print(s1.height)
s1.eat()
# Out:
# 2345
# 25
# Uresh
# 5'10
# Uresh eats less
